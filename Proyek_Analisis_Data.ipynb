# %% [markdown]
# # Proyek Analisis Data: E-Commerce Public Dataset
# - **Nama:** Siti Isyaroh
# - **Email:** sitiisyaroh17@gmail.com
# - **ID Dicoding:** isyaroh

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Produk apa yang paling banyak terjual? Apakah produk tersebut menyumbang revenue terbesar?
# - Lokasi Geografis mana yang menyumpang customers paling banyak?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import urllib
import matplotlib.image as mpimg
from scipy import stats

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### 1.1 Gathering Data

# %% [markdown]
# **1.1.1 Data Customers**

# %%
df_customers = pd.read_csv("E-Commerce Public Dataset/customers_dataset.csv")
df_customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# **1.1.2 Data Geolocations**

# %%
df_geolocations = pd.read_csv("E-Commerce Public Dataset/geolocation_dataset.csv")
df_geolocations.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %% [markdown]
# **1.1.3 Data Order Items**

# %%
df_items = pd.read_csv("E-Commerce Public Dataset/order_items_dataset.csv")
df_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %% [markdown]
# **1.1.4 Data Orders**

# %%
df_orders = pd.read_csv("E-Commerce Public Dataset/orders_dataset.csv")
df_orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %% [markdown]
# **1.1.5 Data Products**

# %%
df_products = pd.read_csv("E-Commerce Public Dataset/products_dataset.csv")
df_products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %% [markdown]
# **1.1.6 Data Payments**

# %%
df_payments = pd.read_csv("E-Commerce Public Dataset/order_payments_dataset.csv")
df_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %% [markdown]
# **1.1.7 Data Reviews**

# %%
df_reviews = pd.read_csv("E-Commerce Public Dataset/order_reviews_dataset.csv")
df_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %% [markdown]
# **1.1.8 Data Kategory**

# %%
df_category = pd.read_csv("E-Commerce Public Dataset/product_category_name_translation.csv")
df_category.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %% [markdown]
# **1.1.9 Data Sellers**

# %%
df_sellers = pd.read_csv("E-Commerce Public Dataset/sellers_dataset.csv")
df_sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ### 1.2 Assessing Data

# %% [markdown]
# **1.2.1 Memeriksa Semua Tipe Data**

# %%
data = {'orders': df_orders,
        'items': df_items,
        'products': df_products,
        'customers': df_customers,
        'geo': df_geolocations,
        'payments' : df_payments,
        'sellers': df_sellers,
        'reviews': df_reviews,
        'category': df_category}

for df_name, df in data.items():
  print('\n', data[df_name].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB
#
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
# ...

# %% [markdown]
# **1.2.2 Memeriksa Data Duplikat**

# %%
duplicate_counts = {}
total_sample_counts = {}

# Calculate and store the duplicate counts and total sample counts for each DataFrame
for df_name, df in data.items():
    duplicate_counts[df_name] = df.duplicated().sum()
    total_sample_counts[df_name] = len(df)  # Calculate the total number of samples

# Create DataFrames from the dictionaries
duplicate_counts_df = pd.DataFrame.from_dict(duplicate_counts, orient='index', columns=['Duplicate Count'])
total_sample_counts_df = pd.DataFrame.from_dict(total_sample_counts, orient='index', columns=['Total Sample Count'])

# Combine the two DataFrames by concatenating them horizontally
pd.concat([total_sample_counts_df, duplicate_counts_df], axis=1)
# Out:
#            Total Sample Count  Duplicate Count
# orders                  99441                0
# items                  112650                0
# products                32951                0
# customers               99441                0
# geo                    738332                0
# payments               103886                0
# sellers                  3095                0
# reviews                 99224                0
# category                   71                0

# %% [markdown]
# - Terdapat data duplikat pada Data Geolocation

# %% [markdown]
# **1.2.3 Memeriksa Missing Value**

# %%
# Initialize a dictionary to store null value counts for each DataFrame
null_counts = {}

# Calculate and store the null value counts for each DataFrame
for df_name, df in data.items():
    null_counts[df_name] = df.isna().sum()
    print(df_name, '\n', null_counts[df_name], '\n')
# Out:
# orders
#  order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64
#
# items
#  order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# products
#  product_id               0
# product_category_name    0
# product_photos_qty       0
# dtype: int64
#
# customers
#  customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# geo
#  geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# ...

# %% [markdown]
# - Terdapat Missing Value pada beberapa kolom Data Order, reviews dan Produk

# %% [markdown]
# ### 1.3 Cleaning Data

# %% [markdown]
# **1.3.1 Data Order**

# %%
print(df_orders['order_status'].value_counts())
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
#Pilih hanya ketike order_status == delivered dengan membuat dataframe baru
df_delivered_orders = df_orders[df_orders['order_status'] == 'delivered']
print(df_delivered_orders['order_status'].value_counts())
# Out:
# order_status
# delivered    96478
# Name: count, dtype: int64

# %% [markdown]
# **1.3.2 Data Products**

# %%
#Hapus rows pada df_products yang tidak berguna
df_products.drop(columns=['product_name_lenght', 'product_description_lenght', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm'], inplace=True)

# %%
#Isi missing value pada rows product_category_name
df_products['product_category_name'].fillna('Others', inplace=True)
#Isi missing value pada rows product_photos_qty
df_products['product_photos_qty'].fillna(value=0, inplace=True)
# Out:
# C:\Users\Siti Isyaroh\AppData\Local\Temp\ipykernel_4612\2574827430.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_products['product_photos_qty'].fillna(value=0, inplace=True)

# %% [markdown]
# **1.3.4 Data Geolocations**

# %%
#Drop data duplikat pada df_geolocation
df_geolocations.drop_duplicates(inplace=True)

# %% [markdown]
# **1.3.5 Data Reviews**

# %%
#Drop rows review_comment_title
df_reviews.drop("review_comment_title", axis=1, inplace=True)

# %%
#Isi Missing value pada rows review_comment_message
df_reviews['review_comment_message'] = np.where(df_reviews['review_comment_message'].isnull(), 0, 1)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Customers

# %%
df_customers.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 69345  4617e05b28548d6730f1d06a9bd3699e  015aba8b6e516fbf6ee76c164c11987b
# 89667  a15995cdfba8c4758aeec7fc37f1df17  602e339dbd10f74605b5da37c4c9d5ca
# 74960  444d3e995b677340acd5c8785a4515dc  f4d1502ace38b0df6f052a5544add9f4
# 97152  9ab11fdb695c99582518b60b74d47879  78815cf059955ab2ca5a6ddecdc2d67a
# 96596  ae07d43e3347a1b8a2121ffa669b931a  0c28edf8b3edcafb768e91462fd09410
#
#        customer_zip_code_prefix       customer_city customer_state
# 69345                     90550        porto alegre             RS
# 89667                     45928       posto da mata             BA
# 74960                     25510  sao joao de meriti             RJ
# 97152                      4475           sao paulo             SP
# 96596                     22793      rio de janeiro             RJ

# %%
df_customers.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=True)
# Out:
# customer_city
# lagoao                1
# pedro gomes           1
# caraibas              1
# japoata               1
# pedro velho           1
#                   ...
# curitiba           1521
# brasilia           2131
# belo horizonte     2773
# rio de janeiro     6882
# sao paulo         15540
# Name: customer_id, Length: 4119, dtype: int64

# %%
df_customers.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# ### Explore Payments

# %%
df_payments.sample(5)
# Out:
#                                order_id  payment_sequential payment_type  \
# 89073  7140f1766a80ed09f082a42b25dfe173                   1       boleto
# 85325  00f98eaeddb9debc8df8cb27e08216d4                   1       boleto
# 11409  4e296794d96b6f50740af9a477b6e9c6                   1       boleto
# 1550   cead9dc81ce08f2255afff2701c569d2                   1  credit_card
# 86342  9089ae7edd24a60e79f8bd277e3c654d                   1  credit_card
#
#        payment_installments  payment_value
# 89073                     1          47.94
# 85325                     1          60.94
# 11409                     1         385.57
# 1550                      8         186.85
# 86342                     1          36.01

# %%
df_payments.groupby(by="payment_type").order_id.nunique().sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76505
# boleto         19784
# voucher         3866
# debit_card      1528
# not_defined        3
# Name: order_id, dtype: int64

# %% [markdown]
# ### Explore Orders

# %%
df_orders.sample(5)
# Out:
#                                order_id                       customer_id  \
# 46466  28b877013b30a7b9edf8ce22fe59087f  676dc133e16631c5a4329fa53d7bfe3d
# 45224  add6fca600991376414a6352a0bf85dc  c9dde713316880ec5a56e0eb8fc0f519
# 68307  47bcc66b360244699053868c95917bd7  6107b1307038a1ce0780b1ac1653fceb
# 7262   f3a43dc5179e476ea1fd032caaed2d9b  284f683869caa2ae4fcbdee78c971871
# 95387  db1c88d4bd1bcbbdb71dae0d17198fc0  5bb6c0af4e7c4e6b89cdb7a358d2ff9f
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 46466    delivered      2018-05-03 10:18:11  2018-05-03 10:57:07
# 45224    delivered      2018-04-20 19:05:57  2018-04-24 19:04:58
# 68307    delivered      2017-11-23 15:01:48  2017-11-24 03:12:13
# 7262     delivered      2017-06-14 21:18:03  2017-06-17 03:44:19
# 95387    delivered      2018-02-04 22:44:34  2018-02-06 03:35:38
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# ...

# %%
df_delivered_orders.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              96478                             96478
# unique                             96478                             96478
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         96478                    96478                96464
# unique            1                    95956                88274
# top       delivered      2017-11-20 10:59:08  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         96476                         96470
# unique                        80106                         95658
# ...

# %% [markdown]
# ### Explore Customers & Orders

# %% [markdown]
# - Merge df_customers dan df_orders

# %%
df_customers_orders = pd.merge(
    left= df_customers,
    right= df_delivered_orders,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)

df_customers_orders.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# - Merge df_payments dan df_reviews

# %%
df_payments_reviews = pd.merge(
    left= df_payments,
    right= df_reviews,
    how="left",
    left_on="order_id",
    right_on="order_id"
)

df_payments_reviews.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
#
#    payment_installments  payment_value                         review_id  \
# 0                     8          99.33  4ce650e117a5b292bf5ea980a61eb61e
# 1                     1          24.39  ad2036caca61484fc435d7e673c020f2
# 2                     1          65.71  bcddfa0f7d2e54cfc74bae4f01b84d92
# 3                     8         107.78  c37a0e51e5df82bdb55d38ff0ffb6af3
# 4                     8         107.78  5bc7680443b4ef765fec11a8201eeb0c
#
#    review_score  review_comment_message review_creation_date  \
# ...

# %%
df_payments_reviews.sort_values(by="payment_value", ascending=False)
# Out:
#                                order_id  payment_sequential payment_type  \
# 52415  03caa2c082116e1d31e67e9ae3700499                   1  credit_card
# 34565  736e1922ae60d0d6a89247b851902527                   1       boleto
# 41660  0812eb902a67711a1cb742b3cdaa65ae                   1  credit_card
# 49871  fefacc66af859508bf1a7934eab1e97f                   1       boleto
# 86018  f5136e38d1a14a4dbd87dff67da82701                   1       boleto
# ...                                 ...                 ...          ...
# 78326  fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
# 51581  4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 37030  fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 94953  c8c528189310eaa44a745b8d9d26908b                   1  not_defined
# 20031  8bcbe01d44d147f901cd3192671144db                   4      voucher
#
#        payment_installments  payment_value                         review_id  \
# ...

# %%
df_payments_reviews.groupby(by="payment_type").agg({
    "order_id" : "nunique",
    "payment_value": ["min", "max"]
})
# Out:
#              order_id payment_value
#               nunique           min       max
# payment_type
# boleto          19784         11.62   7274.88
# credit_card     76505          0.01  13664.08
# debit_card       1528         13.38   4445.50
# not_defined         3          0.00      0.00
# voucher          3866          0.00   3184.34

# %% [markdown]
# - Merge df_customers_orders dan df_payments_reviews

# %%
df_customers_side = pd.merge(
    left=df_customers_orders,
    right=df_payments_reviews,
    how="left",
    left_on="order_id",
    right_on="order_id"
)

df_customers_side.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state  \
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
#
#                            order_id order_status order_purchase_timestamp  \
# ...

# %% [markdown]
# ### Explore Items dan Sellers

# %%
df_items_sellers = pd.merge(
    left=df_items,
    right=df_sellers,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)

df_items_sellers.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0  2017-09-19 09:45:35   58.90          13.29                   27277
# 1  2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %%
df_items_sellers.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
# guarulhos          50
# ibitinga           49
# santo andre        45
# campinas           41
# maringa            40
# Name: seller_id, dtype: int64

# %%
df_items_sellers.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False).head(10)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# Name: seller_id, dtype: int64

# %% [markdown]
# ### Explore Product & Category

# %%
df_product = pd.merge(
    left=df_products,
    right=df_category,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
df_product.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_photos_qty product_category_name_english
# 0                 1.0                     perfumery
# 1                 1.0                           art
# 2                 1.0                sports_leisure
# 3                 1.0                          baby
# 4                 4.0                    housewares

# %%
df_product.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False).head(10)
# Out:
# product_category_name_english
# bed_bath_table           3029
# sports_leisure           2867
# furniture_decor          2657
# health_beauty            2444
# housewares               2335
# auto                     1900
# computers_accessories    1639
# toys                     1411
# watches_gifts            1329
# telephony                1134
# Name: product_id, dtype: int64

# %% [markdown]
# - Merge items_seller dan df_product

# %%
df_sellers_side = pd.merge(
    left=df_product,
    right=df_items_sellers,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
df_sellers_side.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_photos_qty product_category_name_english  \
# 0                 1.0                     perfumery
# 1                 1.0                           art
# 2                 1.0                sports_leisure
# 3                 1.0                          baby
# 4                 4.0                    housewares
#
#                            order_id  order_item_id  \
# 0  e17e4f88e31525f7deef66779844ddce              1
# 1  5236307716393b7114b53ee991f36956              1
# 2  01f66e58769f84129811d43eefd187fb              1
# 3  143d00a4f2dde4e0364ee1821577adb3              1
# ...

# %%
df_sellers_side.sort_values(by="price", ascending=False)
# Out:
#                              product_id              product_category_name  \
# 20528  489ae2aa008f021502940f251d4cce7f              utilidades_domesticas
# 73922  69c590f7ffc7bf8db97190b6cb6ed62e                                pcs
# 49503  1bdf5e6731585cf01aa8169c7028d6ad                              artes
# 71835  a6492cc69376c469ab6f61d8f44de961                    eletroportateis
# 32232  c3ed642d592594bb648ff4a04cee2747                    eletroportateis
# ...                                 ...                                ...
# 55911  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 55903  05b515fdc76e888aada3c6d66c201dff                       beleza_saude
# 29610  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29608  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
# 29609  8a3254bee785a526d548a81a9bc3c9be  construcao_ferramentas_construcao
#
#        product_photos_qty    product_category_name_english  \
# ...

# %%
df_sellers_side.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "price" : ["min", "max"]
})
# Out:
#                               order_id  price
#                                nunique    min      max
# product_category_name_english
# agro_industry_and_commerce         182  12.99  2990.00
# air_conditioning                   253  10.90  1599.00
# art                                202   3.50  6499.00
# arts_and_craftmanship               23   9.80   289.49
# audio                              350  14.90   598.99
# ...                                ...    ...      ...
# stationery                        2311   2.29  1693.00
# tablets_printing_image              79  14.90   889.99
# telephony                         4199   5.00  2428.00
# toys                              3886   4.90  1699.99
# watches_gifts                     5624   8.99  3999.90
#
# [71 rows x 3 columns]

# %% [markdown]
# ### Explore Geolocations

# %%
df_geolocations.sample(5)
# Out:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 872891                        85301       -25.402882       -52.409628
# 838614                        79540       -19.119347       -51.718930
# 705322                        49037       -10.992227       -37.052345
# 167179                         6693       -23.537627       -46.937135
# 496822                        26277       -22.761057       -43.473032
#
#           geolocation_city geolocation_state
# 872891  laranjeiras do sul                PR
# 838614         cassilândia                MS
# 705322             aracaju                SE
# 167179             itapevi                SP
# 496822         nova iguaçu                RJ

# %% [markdown]
# ### Merge All Data

# %%
all_data = pd.merge(
    left=df_customers_side,
    right=df_sellers_side,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
all_data.head(20)
# Out:
#                          customer_id                customer_unique_id  \
# 0   06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1   18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2   4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3   b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4   4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# 5   879864dab9bc3047522c92c82e1212b8  4c93744516667ad3b8f1fb645a3116a4
# 6   fd826e7cf63160e536e0908c76c3f441  addec96d2e059c80c30fe6871d30d177
# 7   5e274e7a0c3809e14aba7ad5aae0d407  57b2a98a409812fe9618067b6b8ebe4f
# 8   5adf08e34b2e993982a47070956c5c65  1175e95fb47ddff9de6b2b06188f7e0d
# 9   4b7139f34592b3a31687243a302fa75b  9afe194fb833f79e300e37e580171f22
# 10  9fb35e4ed6f0a14a4977cd9aea4042bb  2a7745e1ed516b289ed9b29c7d0539a5
# 11  5aa9e4fdd4dfd20959cad2d772509598  2a46fb94aef5cbeeb850418118cee090
# ...

# %%
df_all_data = all_data.drop_duplicates('order_id')

# %%
#Reimport the data because My Mistake that I assign the wrong value so change the whole csv
original_df = pd.read_csv('all_data.csv')
original_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96479 entries, 0 to 96478
# Data columns (total 33 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   customer_id                    96479 non-null  object
#  1   customer_unique_id             96479 non-null  object
#  2   customer_zip_code_prefix       96479 non-null  int64
#  3   customer_city                  96479 non-null  object
#  4   customer_state                 96479 non-null  object
#  5   order_id                       96478 non-null  object
#  6   order_status                   96478 non-null  object
#  7   order_purchase_timestamp       96478 non-null  object
#  8   order_approved_at              96464 non-null  object
#  9   order_delivered_carrier_date   96476 non-null  object
#  10  order_delivered_customer_date  96470 non-null  object
#  11  order_estimated_delivery_date  96478 non-null  object
# ...

# %%
original_df.groupby("customer_state").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                 order_id  payment_value
# customer_state
# SP                 40501     5677858.87
# RJ                 12350     2018480.43
# MG                 11354     1791586.48
# RS                  5345      846573.65
# PR                  4923      770967.23
# SC                  3546      587466.07
# BA                  3256      579450.98
# DF                  2080      339167.86
# GO                  1957      329144.35
# ES                  1995      313144.10
# PE                  1593      304684.50
# CE                  1279      260101.57
# PA                   946      208996.62
# MT                   886      179977.80
# MA                   717      146188.04
# PB                   517      133387.52
# MS                   701      133046.23
# PI                   476      102621.64
# RN                   474       97688.99
# AL                   397       92404.17
# SE                   335       69576.65
# TO                   274       58593.43
# ...

# %%
original_df.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "payment_value": "sum",
}).sort_values(by="payment_value", ascending=False)
# Out:
#                                order_id  payment_value
# product_category_name_english
# health_beauty                      8614     1395646.92
# watches_gifts                      5474     1241921.42
# bed_bath_table                     9187     1203842.05
# sports_leisure                     7490     1103996.21
# computers_accessories              6507     1018903.47
# ...                                 ...            ...
# flowers                              28        1719.45
# home_comfort_2                       24        1321.73
# cds_dvds_musicals                    12         954.99
# fashion_childrens_clothes             6         612.55
# security_and_services                 2         324.51
#
# [71 rows x 2 columns]

# %% [markdown]
# - Kategori produk health_beauty mempunyai jumlah penjualan yang tinggi / produk paling banyak terjual sebanding dengan revenue tertinggi

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:
# - Produk apa yang paling banyak terjual? Apakah produk tersebut menyumbang revenue terbesar?

# %%
no_1 = original_df.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "payment_value": "sum",
}).sort_values(by="payment_value", ascending=False)
no_1
# Out:
#                                order_id  payment_value
# product_category_name_english
# health_beauty                      8614     1395646.92
# watches_gifts                      5474     1241921.42
# bed_bath_table                     9187     1203842.05
# sports_leisure                     7490     1103996.21
# computers_accessories              6507     1018903.47
# ...                                 ...            ...
# flowers                              28        1719.45
# home_comfort_2                       24        1321.73
# cds_dvds_musicals                    12         954.99
# fashion_childrens_clothes             6         612.55
# security_and_services                 2         324.51
#
# [71 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(10, 6))

plt.bar(no_1.index, no_1["payment_value"], color='orange', alpha=0.7, label='Sum of payment')
plt.xlabel('Product Category')
plt.ylabel('Sum of order')
plt.title('Sum of order vs Sum of payment by Product Category')
plt.xticks(rotation=75, ha='right')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Lokasi Geografis mana yang menyumpang customers paling banyak?

# %%
no2= original_df.groupby("customer_state").agg({
    "customer_id": "nunique"
})
no2
# Out:
#                 customer_id
# customer_state
# AC                       80
# AL                      397
# AM                      145
# AP                       67
# BA                     3256
# CE                     1279
# DF                     2080
# ES                     1995
# GO                     1957
# MA                      717
# MG                    11355
# MS                      701
# MT                      886
# PA                      946
# PB                      517
# PE                     1593
# PI                      476
# PR                     4923
# RJ                    12350
# RN                      474
# RO                      243
# RR                       41
# RS                     5345
# SC                     3546
# SE                      335
# SP                    40501
# TO                      274

# %%
import matplotlib.pyplot as plt

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(no2.index, no2["customer_id"], color='blue', alpha=0.7)
plt.xlabel('Customer State')
plt.ylabel('Number of Unique Customers')
plt.title('Distribution of Number of Unique Customers by State')
plt.xticks(rotation=45, ha='right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# - State SP mempunyai jumlah Customers paling banyak berbanding terbalik dengan state RR

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Kategori produk health_beauty mempunyai jumlah penjualan yang tinggi / produk paling banyak terjual sebanding dengan revenue tertinggi
# - State SP mempunyai jumlah Customers paling banyak sekaligus penyumbang revenue terbanyak berbanding terbalik dengan state RR
